# %%
#In this project, we create a web scraper which collects data on an Amazon product and sends and email notification when the price drops below a specified threshold

# %%
#import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib
import csv
import datetime
import pandas as pd

# %%
# Connect to Website

URL = 'https://www.amazon.sg/Python-Nutshell-Desktop-Quick-Reference/dp/1098113551/' #This is the webpage we will scrape

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:126.0) Gecko/20100101 Firefox/126.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content, "html.parser") #Using beautiful soup to parse the HTML contents of the webpage
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text() #Identified the right variables by inspecting HTML elements on the webpage
price = soup2.find('span', class_='a-price-whole').get_text()

# %%
# Creating a csv file to store the scrapped data

price = price.replace(".","").strip()
title = title.strip()
today = datetime.date.today()

header = ['Date','Title','Price']
data = [today,title,price]

with open('AmazonWebScraperData.csv','w', newline = '', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)
# Out:
# Python in a Nutshell: A Desktop Quick Reference
# 96
# 2024-05-24

# %%
df = pd.read_csv(r'C:\Users\Benja\Desktop\Projects\Data Analyst Bootcamp\Untitled Folder\AmazonWebScraperData.csv')

with open('AmazonWebScraperData.csv','a+', newline = '', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

print(df)
# Out:
#          Date                                            Title  Price
# 0  2024-05-24  Python in a Nutshell: A Desktop Quick Reference     96

# %%
# Function to send email to yourself when the price is below a threshold

def send_mail():
 from email.message import EmailMessage
 import ssl
 import smtplib

 email_sender = 'benwee95@gmail.com'
 email_receiver = 'benwee95@gmail.com'
 email_password = '*********'

 subject = "The book you want is below $90! Now is your chance to buy!"
 body = "Go ahead and buy the book!\n https://www.amazon.sg/Python-Nutshell-Desktop-Quick-Reference/dp/1098113551/"

 em = EmailMessage()
 em['From'] = email_sender
 em['To'] = email_receiver
 em['Subject'] = subject
 em.set_content(body)

 context = ssl.create_default_context()
    
send_mail()

# %%
# Function to scrape current data from webpage and update csv file, while also checking if an email needs to be sent

def check_price():
    URL = 'https://www.amazon.sg/Python-Nutshell-Desktop-Quick-Reference/dp/1098113551/'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:126.0) Gecko/20100101 Firefox/126.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    page = requests.get(URL, headers = headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find('span', class_='a-price-whole').get_text()
    
    import datetime
    today = datetime.date.today()
    
    import csv
    
    header = ['Date','Title','Price']
    data = [today,title,price]
    
    if len(title) != 0 and len(price) !=0:
        with open('AmazonWebScraperData.csv','a+', newline = '', encoding='UTF8') as f:
            writer = csv.writer(f)
            writer.writerow(data)
            
    if price < 90:
        send_mail()

# %%
# Checking the price every hour

while(True):
    try:
        check_price()
    except:
        print("error encountered")
        
    time.sleep(3600)
# Out:
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# ...
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# error encountered
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [156], line 7
#       4 except:
#       5     print("error encountered")
# ----> 7 time.sleep(5)
#
# KeyboardInterrupt:

# %%
# Data in csv file

df = pd.read_csv(r'C:\Users\Benja\Desktop\Projects\Data Analyst Bootcamp\Untitled Folder\AmazonWebScraperData.csv')
print(df)
